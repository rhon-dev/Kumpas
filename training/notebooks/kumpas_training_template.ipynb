# %% [markdown]
# # KUMPAS — CNN-LSTM Training Template
#
# Colab template for Phase 2 (model training). **Do not train until the Phase 1 gate is signed off** (`docs/phase-gates.md`).
#
# Experiment logging rule (PRD §7, Model/Training Agent): every run records architecture variant, hyperparameters, and val accuracy in the experiment log — no silent overwriting of previous results.
#
# Targets: ≥90% held-out accuracy → quantized TFLite <150ms inference.

# %% [markdown]
# ## 1. Setup
#
# Runtime → GPU. Mount Drive, install pinned deps (tensorflow, mediapipe versions TBD at Phase 2 gate).

# %%
# Phase 2 — blocked on Phase 1 gate. Setup cells go here.

# %% [markdown]
# ## 2. Data loading
#
# Input: fixed-length landmark sequences from `training/preprocessing/` pipeline (NOT raw video). 50 approved classes only.

# %% [markdown]
# ## 3. CNN-LSTM model
#
# Architecture experiments logged per run: variant name, layers, hyperparams, val accuracy.

# %% [markdown]
# ## 4. Evaluation
#
# Accuracy / precision / recall / F1 + per-class confusion matrix (Adviser reviews this at the Phase 2 gate).

# %% [markdown]
# ## 5. TFLite export (Phase 4)
#
# Post-training quantization → `.tflite` + label map → `training/tflite_export/`. Benchmark on real device, not emulator.
